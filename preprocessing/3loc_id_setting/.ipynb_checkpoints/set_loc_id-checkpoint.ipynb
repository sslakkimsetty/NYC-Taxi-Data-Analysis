# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import string
import os

import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

from timeit import default_timer as timer

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
pd.options.display.max_rows = 5

# %%
dpath = '/Users/sai/Documents/00 NEU/Semester 1/1 DS 5110 - Introduction to Data Management and Processing/Project/NYC-Taxi-Data-Analysis/data_sampled/green/'
shp_path = '/Users/sai/Documents/00 NEU/Semester 1/1 DS 5110 - Introduction to Data Management and Processing/Project/NYC-Taxi-Data-Analysis/taxi_zones/'
curr_dir = os.getcwd()
fname = 'tripdata_green_samp.csv'

# %%
green = pd.read_csv(dpath+fname)

# %%
N = green.shape[0]
rperm = np.random.permutation(N)

# %%
# Hard limits
lon_min = -74.3
lon_max = -73.6

lat_min = 40.4
lat_max = 41.0

# %%
base_map = gpd.read_file(shp_path+'taxi_zones.shp')
base_map = base_map.to_crs({'init': 'epsg:4326'})

# %% [markdown]
# ### Method 1

# %%
geometries = base_map.geometry.values
def assign_locid2(lon, lat):
    point = Point(lon, lat)
    
    for idx, geometry in enumerate(geometries):
        if geometry.contains(point):
            return(idx + 1)
    return(9999)

# %%
n = int(1e+5)
# n = N

green_samp = (
    green
    .iloc[rperm[:n],:]
)

# %%
pulocid = np.ones(n).astype(int)
dolocid = np.ones(n).astype(int)

pulon = green_samp.pickup_longitude.values
pulat = green_samp.pickup_latitude.values

dolon = green_samp.dropoff_longitude.values
dolat = green_samp.dropoff_latitude.values

pulocationid = green_samp.pulocationid.values
dolocationid = green_samp.dolocationid.values

start_ = timer()

for i in range(n):
    if not np.isnan(pulon[i]):
        pulocid[i] = assign_locid2(pulon[i], pulat[i])
        dolocid[i] = assign_locid2(dolon[i], dolat[i])
    else:
        pulocid[i] = pulocationid[i]
        dolocid[i] = dolocationid[i]

print(timer() - start_)
# Out:
# 60.873281105000046

# %%
x = np.array([10, 100, 1000, 10000, 100000])
y = np.array([0.0159, 0.0822, 0.6055, 6.1100, 60.8733])

sns.lineplot(x=x, y=y);

# %%
(60.8733*(N/1000))/(100000)
# Out:
# 4.404039594012

# %% [markdown]
# ### Method 2 - Loops

# %%
n_subs = 10
index_splits = np.array_split(rperm, n_subs)

# %%
# Utility functions

# Get location id from lon-lat pair
geometries = base_map.geometry.values
def assign_locid2(lon, lat):
    point = Point(lon, lat)
    
    for idx, geometry in enumerate(geometries):
        if geometry.contains(point):
            return(idx + 1)
    return(9999)


def print_curr_subset(i_sub, n_subs):
    print("\n\n#####")
    print("Processing subset {0} / {1}".format(i_sub+1, n_subs))


def print_end_of_subset(N, count, n, start_, s_):
    print("\nProcessing ...DONE")
    e_ = timer()
    print("Time taken for {0:.3f}M observations: {1:.3f}".format(n/1e+6, e_-s_))
    print("Time taken until from start of loop: {:.3f}".format(e_-start_))
    print("Total progress: {:.2f}".format(count/N))
    print("#####")

# %%
durations = np.zeros(n_subs)
lengths = [len(array) for array in index_splits]

# %%
count = 0

PULOCID = np.zeros(N)
DOLOCID = np.zeros(N)

start_ = timer()

for i_sub in range(n_subs):
    s_ = timer()
    
    subset = green.iloc[index_splits[i_sub], :]
    n = subset.shape[0]
    print_curr_subset(i_sub, n_subs)
    
    pulocid = np.zeros(n).astype(int)
    dolocid = np.zeros(n).astype(int)

    pulon = subset.pickup_longitude.values
    pulat = subset.pickup_latitude.values

    dolon = subset.dropoff_longitude.values
    dolat = subset.dropoff_latitude.values

    pulocationid = subset.pulocationid.values
    dolocationid = subset.dolocationid.values
    
    for i in range(n):
        if not np.isnan(pulon[i]):
            pulocid[i] = assign_locid2(pulon[i], pulat[i])
            dolocid[i] = assign_locid2(dolon[i], dolat[i])
        else:
            pulocid[i] = pulocationid[i]
            dolocid[i] = dolocationid[i]
    
    PULOCID[count:count+n] = pulocid
    DOLOCID[count:count+n] = dolocid
    
    count = count + n
    durations[i_sub] = timer() - s_
    
    print_end_of_subset(N, count, n, start_, s_)
# Out:
# #####
# Processing subset 1 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 455.254
# Time taken until from start of loop: 455.255
# Total progress: 0.10
# #####
#
#
# #####
# Processing subset 2 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 461.241
# Time taken until from start of loop: 916.495
# Total progress: 0.20
# #####
#
#
# #####
# Processing subset 3 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 430.479
# Time taken until from start of loop: 1346.975
# Total progress: 0.30
# #####
#
#
# #####
# Processing subset 4 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 451.047
# Time taken until from start of loop: 1798.022
# Total progress: 0.40
# #####
#
#
# #####
# Processing subset 5 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 453.971
# Time taken until from start of loop: 2251.992
# Total progress: 0.50
# #####
#
#
# #####
# Processing subset 6 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 458.680
# Time taken until from start of loop: 2710.672
# Total progress: 0.60
# #####
#
#
# #####
# Processing subset 7 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 465.156
# Time taken until from start of loop: 3175.828
# Total progress: 0.70
# #####
#
#
# #####
# Processing subset 8 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 465.730
# Time taken until from start of loop: 3641.557
# Total progress: 0.80
# #####
#
#
# #####
# Processing subset 9 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 450.676
# Time taken until from start of loop: 4092.234
# Total progress: 0.90
# #####
#
#
# #####
# Processing subset 10 / 10
#
# Processing ...DONE
# Time taken for 0.723M observations: 449.920
# Time taken until from start of loop: 4542.153
# Total progress: 1.00
# #####

# %%
green_perm = green.iloc[rperm, :]

# %%
green_perm.head()
# Out:
#          vendorid lpep_pickup_datetime lpep_dropoff_datetime  \
# 5880028         2  2015-12-12 21:56:27   2015-12-12 22:04:52
# 1339568         1  2014-05-10 17:54:57   2014-05-10 18:10:46
# 5925834         2  2015-12-28 19:15:23   2015-12-28 19:22:08
# 4536710         2  2014-08-22 06:47:18   2014-08-22 07:02:34
# 4932038         2  2015-10-19 10:15:08   2015-10-19 10:48:05
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 5880028        -73.964546        40.715477         -73.958710
# 1339568        -73.893402        40.851505         -73.857895
# 5925834        -73.981316        40.689789         -73.966042
# 4536710        -73.945518        40.832947         -74.003052
# 4932038        -73.961182        40.806767         -73.972717
#
#          dropoff_latitude  pulocationid  dolocationid  trip_distance  ...  \
# 5880028         40.713448           NaN           NaN           1.30  ...
# 1339568         40.880135           NaN           NaN           6.00  ...
# 5925834         40.693432           NaN           NaN           1.11  ...
# 4536710         40.756271           NaN           NaN           7.10  ...
# 4932038         40.756344           NaN           NaN           4.40  ...
#
#          fare_amount  tip_amount  extra  tolls_amount  improvement_surcharge  \
# 5880028          7.5        0.00    0.5           0.0                    0.3
# 1339568         19.5        0.00    0.0           0.0                    NaN
# 5925834          6.5        1.66    1.0           0.0                    0.3
# 4536710         21.5        0.00    0.0           0.0                    NaN
# 4932038         22.0        4.56    0.0           0.0                    0.3
#
#          ehail_fee  mta_tax  ratecodeid  passenger_count  store_and_fwd_flag
# 5880028        NaN      0.5           1                6                   N
# 1339568        NaN      0.5           1                1                   N
# 5925834        NaN      0.5           1                1                   N
# 4536710        NaN      0.5           1                1                   N
# 4932038        NaN      0.5           1                5                   N
#
# [5 rows x 23 columns]

# %%
green_perm.loc[:,'pulocationid'] = PULOCID
green_perm.loc[:,'dolocationid'] = DOLOCID

# %%
green_perm.head()
# Out:
#          vendorid lpep_pickup_datetime lpep_dropoff_datetime  \
# 5880028         2  2015-12-12 21:56:27   2015-12-12 22:04:52
# 1339568         1  2014-05-10 17:54:57   2014-05-10 18:10:46
# 5925834         2  2015-12-28 19:15:23   2015-12-28 19:22:08
# 4536710         2  2014-08-22 06:47:18   2014-08-22 07:02:34
# 4932038         2  2015-10-19 10:15:08   2015-10-19 10:48:05
#
#          pickup_longitude  pickup_latitude  dropoff_longitude  \
# 5880028        -73.964546        40.715477         -73.958710
# 1339568        -73.893402        40.851505         -73.857895
# 5925834        -73.981316        40.689789         -73.966042
# 4536710        -73.945518        40.832947         -74.003052
# 4932038        -73.961182        40.806767         -73.972717
#
#          dropoff_latitude  pulocationid  dolocationid  trip_distance  ...  \
# 5880028         40.713448         256.0         256.0           1.30  ...
# 1339568         40.880135          78.0         254.0           6.00  ...
# 5925834         40.693432          97.0          49.0           1.11  ...
# 4536710         40.756271         244.0         246.0           7.10  ...
# 4932038         40.756344         166.0         162.0           4.40  ...
#
#          fare_amount  tip_amount  extra  tolls_amount  improvement_surcharge  \
# 5880028          7.5        0.00    0.5           0.0                    0.3
# 1339568         19.5        0.00    0.0           0.0                    NaN
# 5925834          6.5        1.66    1.0           0.0                    0.3
# 4536710         21.5        0.00    0.0           0.0                    NaN
# 4932038         22.0        4.56    0.0           0.0                    0.3
#
#          ehail_fee  mta_tax  ratecodeid  passenger_count  store_and_fwd_flag
# 5880028        NaN      0.5           1                6                   N
# 1339568        NaN      0.5           1                1                   N
# 5925834        NaN      0.5           1                1                   N
# 4536710        NaN      0.5           1                1                   N
# 4932038        NaN      0.5           1                5                   N
#
# [5 rows x 23 columns]

# %%
green_perm.to_csv(dpath + 'green_samp_locid.csv', index=False)

# %%
green_samp_locid = pd.read_csv(dpath + 'green_samp_locid.csv')
green_samp_locid.head()
