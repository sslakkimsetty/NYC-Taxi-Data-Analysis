# %%
import numpy as np
import pandas as pd
import string
import os
from timeit import default_timer as timer

import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
pd.options.display.max_rows = 5

# %%
dpath = '/Users/sai/Documents/00 NEU/Semester 1/1 DS 5110 - Introduction to Data Management and Processing/Project/NYC-Taxi-Data-Analysis/data_sampled/green/'
shp_path = '/Users/sai/Downloads/taxi_zones/'
curr_dir = os.getcwd()
csv_fnames = list(os.walk(dpath))[0][2]
csv_fnames
# Out:
# ['green_tripdata_2017-09.csv',
#  'green_tripdata_2015-08.csv',
#  'green_tripdata_2015-09.csv',
#  'green_tripdata_2014-12.csv',
#  'green_tripdata_2014-06.csv',
#  'green_tripdata_2018-06.csv',
#  'green_tripdata_2018-12.csv',
#  'green_tripdata_2016-03.csv',
#  'green_tripdata_2016-02.csv',
#  'green_tripdata_2018-07.csv',
#  'green_tripdata_2014-07.csv',
#  'green_tripdata_2014-05.csv',
#  'green_tripdata_2014-11.csv',
#  'green_tripdata_2018-11.csv',
#  'green_tripdata_2018-05.csv',
#  'green_tripdata_2016-01.csv',
#  'green_tripdata_2018-04.csv',
#  'green_tripdata_2018-10.csv',
#  'green_tripdata_2014-10.csv',
#  'green_tripdata_2014-04.csv',
#  'green_tripdata_2013-09.csv',
#  'green_tripdata_2016-05.csv',
#  'green_tripdata_2016-11.csv',
#  'green_tripdata_2018-01.csv',
#  'green_tripdata_2016-10.csv',
#  'green_tripdata_2016-04.csv',
#  'green_tripdata_2014-01.csv',
#  'green_tripdata_2013-08.csv',
#  'green_tripdata_2014-03.csv',
#  'green_tripdata_2016-12.csv',
#  'green_tripdata_2016-06.csv',
#  'green_tripdata_2018-03.csv',
#  'green_tripdata_2018-02.csv',
#  'green_tripdata_2016-07.csv',
#  'green_tripdata_2014-02.csv',
#  'green_tripdata_2013-12.csv',
#  'green_tripdata_2013-11.csv',
#  'green_tripdata_2016-09.csv',
#  'green_tripdata_2016-08.csv',
#  'green_tripdata_2013-10.csv',
#  'green_tripdata_2014-09.csv',
#  'green_tripdata_2018-09.csv',
#  'green_tripdata_2018-08.csv',
#  'green_tripdata_2014-08.csv',
#  'green_tripdata_2017-01.csv',
#  'green_tripdata_2015-04.csv',
#  'green_tripdata_2015-10.csv',
#  'green_tripdata_2015-11.csv',
#  'green_tripdata_2015-05.csv',
#  'green_tripdata_2017-02.csv',
#  'green_tripdata_2015-07.csv',
#  'green_tripdata_2015-06.csv',
#  'green_tripdata_2015-12.csv',
#  'green_tripdata_2017-03.csv',
#  'green_tripdata_2017-07.csv',
#  'green_tripdata_2015-02.csv',
#  'green_tripdata_2015-03.csv',
#  'green_tripdata_2017-06.csv',
#  'green_tripdata_2017-12.csv',
#  'green_tripdata_2017-04.csv',
#  'green_tripdata_2017-10.csv',
#  'green_tripdata_2015-01.csv',
#  'green_tripdata_2017-11.csv',
#  'green_tripdata_2017-05.csv']

# %%
for fname in csv_fnames:
    with open(dpath+fname, 'r') as f:
        header = f.readline()
        print(fname)
        colnames = header.split(',')
        colnames[-1] = colnames[-1][:-1]
        print(colnames)
    break
# Out:
# green_tripdata_2017-09.csv
# ['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime', 'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID', 'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax', 'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge', 'total_amount', 'payment_type', 'trip_type']

# %%
fname1 = 'green_tripdata_2014-09.csv'
fname2 = 'green_tripdata_2018-09.csv'

df1 = pd.read_csv(dpath+fname1)
df1.columns = [col.lower().strip() for col in df1.columns]

df2 = pd.read_csv(dpath+fname2)
df1
df2.columns = [col.lower().strip() for col in df2.columns]

pd.concat([df1, df2], axis=0, ignore_index=True, sort=True)
# Out:
#         dolocationid  dropoff_latitude  dropoff_longitude  ehail_fee  extra  \
# 0                NaN         40.725163         -73.984093        NaN    0.5
# 1                NaN         40.718536         -73.985367        NaN    0.0
# ...              ...               ...                ...        ...    ...
# 202858         236.0               NaN                NaN        NaN    0.0
# 202859         238.0               NaN                NaN        NaN    0.5
#
#         fare_amount  improvement_surcharge lpep_dropoff_datetime  \
# 0              20.0                    NaN   2014-09-26 22:01:14
# 1              19.0                    NaN   2014-09-20 15:02:31
# ...             ...                    ...                   ...
# 202858          6.0                    0.3   2018-09-16 11:59:09
# 202859          8.5                    0.3   2018-09-06 22:18:24
#
#        lpep_pickup_datetime  mta_tax  ...  pickup_longitude  pulocationid  \
# 0       2014-09-26 21:43:09      0.5  ...        -73.917862           NaN
# 1       2014-09-20 14:43:43      0.5  ...        -73.992210           NaN
# ...                     ...      ...  ...               ...           ...
# 202858  2018-09-16 11:53:32      0.5  ...               NaN          43.0
# 202859  2018-09-06 22:09:33      0.5  ...               NaN          75.0
#
#         ratecodeid  store_and_fwd_flag  tip_amount  tolls_amount total_amount  \
# 0                1                   N        5.12           0.0        26.12
# 1                1                   N        5.85           0.0        25.35
# ...            ...                 ...         ...           ...          ...
# 202858           1                   N        1.00           0.0         7.80
# 202859           1                   N        0.00           0.0         9.80
#
#         trip_distance  trip_type  vendorid
# 0                5.67        1.0         2
# 1                5.10        1.0         1
# ...               ...        ...       ...
# 202858           1.20        1.0         2
# 202859           1.71        1.0         2
#
# [202860 rows x 23 columns]

# %%
df2
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2018-09-08 00:17:10   2018-09-08 00:23:38                  N
# 1             1  2018-09-10 12:13:53   2018-09-10 12:17:57                  N
# ...         ...                  ...                   ...                ...
# 66669         2  2018-09-16 11:53:32   2018-09-16 11:59:09                  N
# 66670         2  2018-09-06 22:09:33   2018-09-06 22:18:24                  N
#
#        RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0               1            25           106                1           1.25
# 1               1            75           236                1           0.40
# ...           ...           ...           ...              ...            ...
# 66669           1            43           236                1           1.20
# 66670           1            75           238                5           1.71
#
#        fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0              7.0    0.5      0.5        0.00           0.0        NaN
# 1              4.5    0.0      0.5        1.05           0.0        NaN
# ...            ...    ...      ...         ...           ...        ...
# 66669          6.0    0.0      0.5        1.00           0.0        NaN
# 66670          8.5    0.5      0.5        0.00           0.0        NaN
#
#        improvement_surcharge  total_amount  payment_type  trip_type
# 0                        0.3          8.30             2        1.0
# 1                        0.3          6.35             1        1.0
# ...                      ...           ...           ...        ...
# 66669                    0.3          7.80             1        1.0
# 66670                    0.3          9.80             2        1.0
#
# [66671 rows x 19 columns]

# %%
list(set(df1.columns) - set(df2.columns))
# Out:
# ['dropoff_longitude',
#  'pickup_latitude',
#  'dropoff_latitude',
#  'pickup_longitude']

# %%
list(set(df2.columns) - set(df1.columns))
# Out:
# ['pulocationid', 'improvement_surcharge', 'dolocationid']

# %% [markdown]
# ####
# 1. df1 has 1 column more than df2 (lat, lon, lat, lon vs. locid, locid, surcharge).
# 2. df1 and df2 share 16 columns (df1 = 16+4, df2 = 16+3).
# 3. concat df would have 23 columns (16 + 4 + 3).

# %% [markdown]
# ###  Loop to concat all files

# %%
# Initializing concatenated dataframe and timers
stime = timer()
concat_df = pd.read_csv(dpath + csv_fnames[0])
concat_df.columns = [col.lower().strip() for col in concat_df.columns]

concat_dur = [timer()-stime]
concat_obs = [concat_df.shape[0]]

for idx, fname in enumerate(csv_fnames[1:]):
    print("\n------")
    print("File {0} of {1}".format(idx + 2, len(csv_fnames)))
    print("BEFORE CONCAT: Line count: {}".format(concat_df.shape[0]))

    stime_ = timer()

    curr_df = pd.read_csv(dpath + fname)
    curr_df.columns = [col.lower().strip() for col in curr_df.columns]
    concat_df = pd.concat([concat_df, curr_df], axis=0, ignore_index=True, sort=True)

    etime_ = timer()
    concat_dur.append(etime_-stime_)
    concat_obs.append(curr_df.shape[0])

    print("AFTER CONCAT: Line count: {}".format(concat_df.shape[0]))
    print("Time elapsed: {0:.3f}".format(etime_ - stime_))
    print("Observations added:", str(curr_df.shape[0]))
    print("------\n")


print("TOTAL TIME OF CONCATENATION: {0:.3f}".format(timer() - stime))

# Write data to .csv
concat_df.to_csv(dpath + 'tripdata_green_samp', index=False)
# Out:
# ------
# File 2 of 64
# BEFORE CONCAT: Line count: 88246
# AFTER CONCAT: Line count: 241480
# Time elapsed: 0.530
# Observations added: 153234
# ------
#
#
# ------
# File 3 of 64
# BEFORE CONCAT: Line count: 241480
# AFTER CONCAT: Line count: 390973
# Time elapsed: 0.703
# Observations added: 149493
# ------
#
#
# ------
# File 4 of 64
# BEFORE CONCAT: Line count: 390973
# AFTER CONCAT: Line count: 555552
# Time elapsed: 0.725
# Observations added: 164579
# ------
#
#
# ------
# File 5 of 64
# BEFORE CONCAT: Line count: 555552
# AFTER CONCAT: Line count: 689328
# Time elapsed: 0.788
# Observations added: 133776
# ------
#
#
# ------
# File 6 of 64
# BEFORE CONCAT: Line count: 689328
# AFTER CONCAT: Line count: 763265
# Time elapsed: 0.498
# Observations added: 73937
# ------
#
#
# ------
# File 7 of 64
# BEFORE CONCAT: Line count: 763265
# AFTER CONCAT: Line count: 831802
# Time elapsed: 0.538
# Observations added: 68537
# ------
#
#
# ------
# File 8 of 64
# BEFORE CONCAT: Line count: 831802
# AFTER CONCAT: Line count: 989441
# Time elapsed: 0.958
# Observations added: 157639
# ------
#
#
# ------
# File 9 of 64
# BEFORE CONCAT: Line count: 989441
# AFTER CONCAT: Line count: 1140513
# Time elapsed: 1.179
# Observations added: 151072
# ------
#
#
# ------
# File 10 of 64
# BEFORE CONCAT: Line count: 1140513
# AFTER CONCAT: Line count: 1208959
# Time elapsed: 0.784
# Observations added: 68446
# ------
#
#
# ------
# File 11 of 64
# BEFORE CONCAT: Line count: 1208959
# AFTER CONCAT: Line count: 1336356
# Time elapsed: 0.974
# Observations added: 127397
# ------
#
#
# ------
# File 12 of 64
# BEFORE CONCAT: Line count: 1336356
# AFTER CONCAT: Line count: 1478506
# Time elapsed: 1.024
# Observations added: 142150
# ------
#
#
# ------
# File 13 of 64
# BEFORE CONCAT: Line count: 1478506
# AFTER CONCAT: Line count: 1633322
# Time elapsed: 1.093
# Observations added: 154816
# ------
#
#
# ------
# File 14 of 64
# BEFORE CONCAT: Line count: 1633322
# AFTER CONCAT: Line count: 1698979
# Time elapsed: 0.871
# Observations added: 65657
# ------
#
#
# ------
# File 15 of 64
# BEFORE CONCAT: Line count: 1698979
# AFTER CONCAT: Line count: 1778702
# Time elapsed: 0.909
# Observations added: 79723
# ------
#
#
# ------
# File 16 of 64
# BEFORE CONCAT: Line count: 1778702
# AFTER CONCAT: Line count: 1923230
# Time elapsed: 1.291
# Observations added: 144528
# ------
#
#
# ------
# File 17 of 64
# BEFORE CONCAT: Line count: 1923230
# AFTER CONCAT: Line count: 2003238
# Time elapsed: 0.992
# Observations added: 80008
# ------
#
#
# ------
# File 18 of 64
# BEFORE CONCAT: Line count: 2003238
# AFTER CONCAT: Line count: 2074289
# Time elapsed: 0.991
# Observations added: 71051
# ------
#
#
# ------
# File 19 of 64
# BEFORE CONCAT: Line count: 2074289
# AFTER CONCAT: Line count: 2223416
# Time elapsed: 1.345
# Observations added: 149127
# ------
#
#
# ------
# File 20 of 64
# BEFORE CONCAT: Line count: 2223416
# AFTER CONCAT: Line count: 2354332
# Time elapsed: 1.355
# Observations added: 130916
# ------
#
#
# ------
# File 21 of 64
# BEFORE CONCAT: Line count: 2354332
# AFTER CONCAT: Line count: 2359297
# Time elapsed: 0.964
# Observations added: 4965
# ------
#
#
# ------
# File 22 of 64
# BEFORE CONCAT: Line count: 2359297
# AFTER CONCAT: Line count: 2512995
# Time elapsed: 1.541
# Observations added: 153698
# ------
#
#
# ------
# File 23 of 64
# BEFORE CONCAT: Line count: 2512995
# AFTER CONCAT: Line count: 2627816
# Time elapsed: 1.309
# Observations added: 114821
# ------
#
#
# ------
# File 24 of 64
# BEFORE CONCAT: Line count: 2627816
# AFTER CONCAT: Line count: 2707169
# Time elapsed: 1.284
# Observations added: 79353
# ------
#
#
# ------
# File 25 of 64
# BEFORE CONCAT: Line count: 2707169
# AFTER CONCAT: Line count: 2832426
# Time elapsed: 1.422
# Observations added: 125257
# ------
#
#
# ------
# File 26 of 64
# BEFORE CONCAT: Line count: 2832426
# AFTER CONCAT: Line count: 2986818
# Time elapsed: 1.783
# Observations added: 154392
# ------
#
#
# ------
# File 27 of 64
# BEFORE CONCAT: Line count: 2986818
# AFTER CONCAT: Line count: 3067203
# Time elapsed: 1.534
# Observations added: 80385
# ------
#
#
# ------
# File 28 of 64
# BEFORE CONCAT: Line count: 3067203
# AFTER CONCAT: Line count: 3067965
# Time elapsed: 1.309
# Observations added: 762
# ------
#
#
# ------
# File 29 of 64
# BEFORE CONCAT: Line count: 3067965
# AFTER CONCAT: Line count: 3197312
# Time elapsed: 1.762
# Observations added: 129347
# ------
#
#
# ------
# File 30 of 64
# BEFORE CONCAT: Line count: 3197312
# AFTER CONCAT: Line count: 3319728
# Time elapsed: 1.679
# Observations added: 122416
# ------
#
#
# ------
# File 31 of 64
# BEFORE CONCAT: Line count: 3319728
# AFTER CONCAT: Line count: 3460201
# Time elapsed: 2.216
# Observations added: 140473
# ------
#
#
# ------
# File 32 of 64
# BEFORE CONCAT: Line count: 3460201
# AFTER CONCAT: Line count: 3543916
# Time elapsed: 1.753
# Observations added: 83715
# ------
#
#
# ------
# File 33 of 64
# BEFORE CONCAT: Line count: 3543916
# AFTER CONCAT: Line count: 3620910
# Time elapsed: 1.687
# Observations added: 76994
# ------
#
#
# ------
# File 34 of 64
# BEFORE CONCAT: Line count: 3620910
# AFTER CONCAT: Line count: 3754161
# Time elapsed: 1.986
# Observations added: 133251
# ------
#
#
# ------
# File 35 of 64
# BEFORE CONCAT: Line count: 3754161
# AFTER CONCAT: Line count: 3854685
# Time elapsed: 2.043
# Observations added: 100524
# ------
#
#
# ------
# File 36 of 64
# BEFORE CONCAT: Line count: 3854685
# AFTER CONCAT: Line count: 3914941
# Time elapsed: 1.948
# Observations added: 60256
# ------
#
#
# ------
# File 37 of 64
# BEFORE CONCAT: Line count: 3914941
# AFTER CONCAT: Line count: 3953038
# Time elapsed: 1.886
# Observations added: 38097
# ------
#
#
# ------
# File 38 of 64
# BEFORE CONCAT: Line count: 3953038
# AFTER CONCAT: Line count: 4069275
# Time elapsed: 2.102
# Observations added: 116237
# ------
#
#
# ------
# File 39 of 64
# BEFORE CONCAT: Line count: 4069275
# AFTER CONCAT: Line count: 4194043
# Time elapsed: 2.076
# Observations added: 124768
# ------
#
#
# ------
# File 40 of 64
# BEFORE CONCAT: Line count: 4194043
# AFTER CONCAT: Line count: 4211044
# Time elapsed: 1.992
# Observations added: 17001
# ------
#
#
# ------
# File 41 of 64
# BEFORE CONCAT: Line count: 4211044
# AFTER CONCAT: Line count: 4347233
# Time elapsed: 2.424
# Observations added: 136189
# ------
#
#
# ------
# File 42 of 64
# BEFORE CONCAT: Line count: 4347233
# AFTER CONCAT: Line count: 4413904
# Time elapsed: 2.148
# Observations added: 66671
# ------
#
#
# ------
# File 43 of 64
# BEFORE CONCAT: Line count: 4413904
# AFTER CONCAT: Line count: 4480542
# Time elapsed: 2.210
# Observations added: 66638
# ------
#
#
# ------
# File 44 of 64
# BEFORE CONCAT: Line count: 4480542
# AFTER CONCAT: Line count: 4615036
# Time elapsed: 2.556
# Observations added: 134494
# ------
#
#
# ------
# File 45 of 64
# BEFORE CONCAT: Line count: 4615036
# AFTER CONCAT: Line count: 4722062
# Time elapsed: 2.401
# Observations added: 107026
# ------
#
#
# ------
# File 46 of 64
# BEFORE CONCAT: Line count: 4722062
# AFTER CONCAT: Line count: 4888501
# Time elapsed: 2.721
# Observations added: 166439
# ------
#
#
# ------
# File 47 of 64
# BEFORE CONCAT: Line count: 4888501
# AFTER CONCAT: Line count: 5051555
# Time elapsed: 2.786
# Observations added: 163054
# ------
#
#
# ------
# File 48 of 64
# BEFORE CONCAT: Line count: 5051555
# AFTER CONCAT: Line count: 5204553
# Time elapsed: 2.877
# Observations added: 152998
# ------
#
#
# ------
# File 49 of 64
# BEFORE CONCAT: Line count: 5204553
# AFTER CONCAT: Line count: 5383238
# Time elapsed: 3.109
# Observations added: 178685
# ------
#
#
# ------
# File 50 of 64
# BEFORE CONCAT: Line count: 5383238
# AFTER CONCAT: Line count: 5485564
# Time elapsed: 2.820
# Observations added: 102326
# ------
#
#
# ------
# File 51 of 64
# BEFORE CONCAT: Line count: 5485564
# AFTER CONCAT: Line count: 5639731
# Time elapsed: 3.086
# Observations added: 154167
# ------
#
#
# ------
# File 52 of 64
# BEFORE CONCAT: Line count: 5639731
# AFTER CONCAT: Line count: 5803618
# Time elapsed: 3.269
# Observations added: 163887
# ------
#
#
# ------
# File 53 of 64
# BEFORE CONCAT: Line count: 5803618
# AFTER CONCAT: Line count: 5964447
# Time elapsed: 3.249
# Observations added: 160829
# ------
#
#
# ------
# File 54 of 64
# BEFORE CONCAT: Line count: 5964447
# AFTER CONCAT: Line count: 6080311
# Time elapsed: 3.018
# Observations added: 115864
# ------
#
#
# ------
# File 55 of 64
# BEFORE CONCAT: Line count: 6080311
# AFTER CONCAT: Line count: 6171789
# Time elapsed: 2.998
# Observations added: 91478
# ------
#
#
# ------
# File 56 of 64
# BEFORE CONCAT: Line count: 6171789
# AFTER CONCAT: Line count: 6329272
# Time elapsed: 3.423
# Observations added: 157483
# ------
#
#
# ------
# File 57 of 64
# BEFORE CONCAT: Line count: 6329272
# AFTER CONCAT: Line count: 6501529
# Time elapsed: 3.474
# Observations added: 172257
# ------
#
#
# ------
# File 58 of 64
# BEFORE CONCAT: Line count: 6501529
# AFTER CONCAT: Line count: 6599176
# Time elapsed: 3.853
# Observations added: 97647
# ------
#
#
# ------
# File 59 of 64
# BEFORE CONCAT: Line count: 6599176
# AFTER CONCAT: Line count: 6689800
# Time elapsed: 3.477
# Observations added: 90624
# ------
#
#
# ------
# File 60 of 64
# BEFORE CONCAT: Line count: 6689800
# AFTER CONCAT: Line count: 6797977
# Time elapsed: 3.201
# Observations added: 108177
# ------
#
#
# ------
# File 61 of 64
# BEFORE CONCAT: Line count: 6797977
# AFTER CONCAT: Line count: 6890551
# Time elapsed: 3.464
# Observations added: 92574
# ------
#
#
# ------
# File 62 of 64
# BEFORE CONCAT: Line count: 6890551
# AFTER CONCAT: Line count: 7041401
# Time elapsed: 3.808
# Observations added: 150850
# ------
#
#
# ------
# File 63 of 64
# BEFORE CONCAT: Line count: 7041401
# AFTER CONCAT: Line count: 7128818
# Time elapsed: 3.536
# Observations added: 87417
# ------
#
#
# ------
# File 64 of 64
# BEFORE CONCAT: Line count: 7128818
# AFTER CONCAT: Line count: 7234764
# Time elapsed: 4.011
# Observations added: 105946
# ------
#
# TOTAL TIME OF CONCATENATION: 125.996

# %%
concat_df.shape
# Out:
# (7234764, 23)

# %%
concat_df
# Out:
#          dolocationid  dropoff_latitude  dropoff_longitude  ehail_fee  extra  \
# 0                41.0               NaN                NaN        NaN    0.0
# 1                42.0               NaN                NaN        NaN    0.5
# ...               ...               ...                ...        ...    ...
# 7234762          61.0               NaN                NaN        NaN    0.0
# 7234763         116.0               NaN                NaN        NaN    0.0
#
#          fare_amount  improvement_surcharge lpep_dropoff_datetime  \
# 0                8.0                    0.3   2017-09-27 08:11:36
# 1                4.5                    0.3   2017-09-09 22:46:57
# ...              ...                    ...                   ...
# 7234762         11.0                    0.3   2017-05-06 06:35:54
# 7234763          6.5                    0.3   2017-05-05 09:20:31
#
#         lpep_pickup_datetime  mta_tax  ...  pickup_longitude  pulocationid  \
# 0        2017-09-27 08:03:46      0.5  ...               NaN          75.0
# 1        2017-09-09 22:44:39      0.5  ...               NaN          42.0
# ...                      ...      ...  ...               ...           ...
# 7234762  2017-05-06 06:25:00      0.5  ...               NaN         256.0
# 7234763  2017-05-05 09:12:51      0.5  ...               NaN          42.0
#
#          ratecodeid  store_and_fwd_flag  tip_amount  tolls_amount  \
# 0                 1                   N         1.0           0.0
# 1                 1                   N         0.0           0.0
# ...             ...                 ...         ...           ...
# 7234762           1                   N         0.0           0.0
# 7234763           1                   N         0.0           0.0
#
#         total_amount  trip_distance  trip_type  vendorid
# 0                9.8           1.66        1.0         2
# 1                5.8           0.67        1.0         2
# ...              ...            ...        ...       ...
# 7234762         11.8           2.63        1.0         2
# 7234763          7.3           0.67        1.0         2
#
# [7234764 rows x 23 columns]

# %%
x = range(1,len(concat_obs)+1)
y1 = concat_obs
y2 = concat_dur

fig, ax1 = plt.subplots(1, figsize=(6,4))
sns.scatterplot(x=x, y=y1, ax=ax1)

ax2 = plt.twinx()
sns.lineplot(x=x, y=y2, ax=ax2, color='orange', label='duration (s)', legend='full');

# %%
shape = (len(concat_obs),1)
obs = np.array(concat_obs).reshape(shape)

cum_obs = np.roll(obs.cumsum(),1).reshape(shape)
cum_obs[0] = 0
# cum_obs

# %%
X = np.hstack((np.ones(obs.shape), obs, cum_obs))
y = np.array(concat_dur)

dur = pd.DataFrame(np.hstack((X, y.reshape(obs.shape))),
                   columns=['X0','curr_obs', 'cum_obs', 'dur'])
dur.head()
# Out:
#     X0  curr_obs   cum_obs       dur
# 0  1.0   88246.0       0.0  0.236188
# 1  1.0  153234.0   88246.0  0.530493
# 2  1.0  149493.0  241480.0  0.702545
# 3  1.0  164579.0  390973.0  0.725008
# 4  1.0  133776.0  555552.0  0.788216

# %%
X = X[:,[0,2]]

A = np.linalg.inv(X.T.dot(X))
B = X.T.dot(y)

thetas = A.dot(B)
print(thetas)
y_hat = X.dot(thetas)
# Out:
# [2.71254684e-01 4.82995481e-07]

# %%
fig, ax1 = plt.subplots(1, figsize=(6,4))
sns.scatterplot(x='cum_obs', y='dur', data=dur, ax=ax1)

sns.lineplot(x=dur.cum_obs, y=y_hat, color='orange', label='duration (prediction)');
